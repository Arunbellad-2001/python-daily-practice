# %%
## creating empty dictionaries

empty_dict={}
print(type(empty_dict))
print(empty_dict)
# Out:
# <class 'dict'>
# {}

# %%
students={"name":"Arun","age":35,"grade":"A"}
print(students)
# Out:
# {'name': 'Arun', 'age': 35, 'grade': 'A'}

# %%
## accseing wlments
print(students['grade'])
print(students['age'])
print(students['name'])


print(students.get('grade'))
print(students.get('last_name'))
print(students.get('last_name',"not avalible"))
# Out:
# A
# 35
# Arun
# A
# None
# not avalible

# %%
## ## Modifying Dicitonary Elements
## Dictionary are mutable,so you can add, update or delete elements
print(students)
# Out:
# {'name': 'Arun', 'age': 35, 'grade': 'A'}

# %%
students["age"]=33
print(students)
students["Address"]="karnataka"
print(students)
students["year of passout"]=2023
print(students)
# Out:
# {'name': 'Arun', 'age': 33, 'grade': 'A'}
# {'name': 'Arun', 'age': 33, 'grade': 'A', 'Address': 'karnataka'}
# {'name': 'Arun', 'age': 33, 'grade': 'A', 'Address': 'karnataka', 'year of passout': 2023}

# %%
students["grade"]="A+"
print(students)
# Out:
# {'name': 'Arun', 'age': 33, 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}

# %%
del students['age']
print(students)
# Out:
# {'name': 'Arun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}

# %%
## Dictionary methods
key=students.keys()
print(key)

value=students.values()
print(value)

item=students.items()
print(item)
# Out:
# dict_keys(['name', 'grade', 'Address', 'year of passout'])
# dict_values(['Arun', 'A+', 'karnataka', 2023])
# dict_items([('name', 'Arun'), ('grade', 'A+'), ('Address', 'karnataka'), ('year of passout', 2023)])

# %%
## shallow copy
student_copy=students
print(students)
print(student_copy)
# Out:
# {'name': 'Arun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}
# {'name': 'Arun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}

# %%
students["name"]="varun"
print(students)
print(students)
# Out:
# {'name': 'varun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}
# {'name': 'varun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}

# %%
student_copy1=students.copy()
print(student_copy1)
print(students)
# Out:
# {'name': 'varun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}
# {'name': 'varun', 'grade': 'A+', 'Address': 'karnataka', 'year of passout': 2023}

# %%
### Iterating Over Dictionaries
## You can use loops to iterate over dictionatries, keys,values,or items

## Iterating over keys
for keys in students.keys():
    print(keys)
# Out:
# name
# grade
# Address
# year of passout

# %%
for values in students.values():
    print(values)
# Out:
# varun
# A+
# karnataka
# 2023

# %%
## Iterate over key value pairs

for key,value in students.items():
    print(f"{key}:{value}")
# Out:
# name:varun
# grade:A+
# Address:karnataka
# year of passout:2023

# %%
## Nested Disctionaries

students={
    "student1":{"name":"arun","age":24},
    "student2":{"name":"varun","age":23}
}
print(students)
# Out:
# {'student1': {'name': 'arun', 'age': 24}, 'student2': {'name': 'varun', 'age': 23}}

# %%
## Access nested dictionaries elementss
print(students["student1"]["name"])
print(students["student2"]["age"])
# Out:
# arun
# 23

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'arun', 'age': 24}), ('student2', {'name': 'varun', 'age': 23})])

# %%
## iterating over neatsed list dictionaries
for students_id, students_info in students.items():
    print(f"{students_id}:{students_info}")
    for key,value in students_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'arun', 'age': 24}
# name:arun
# age:24
# student2:{'name': 'varun', 'age': 23}
# name:varun
# age:23

# %%
## condition dectionaries compheration
